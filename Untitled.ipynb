# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.1'

# %%
import matplotlib.pyplot as plt

# %%
savings = [634, 322, 435, 754, 234, 346]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June']

# %%
plt.plot(months, savings)
plt.xlabel('Month')
plt.ylabel('Savings ($)')
plt.title('Savings Account Results')
plt.show()
